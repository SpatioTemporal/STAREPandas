# %%
import starepandas

# %%
ssmis = starepandas.io.granules.SSMIS(file_path='../tests/data/granules/1C.F16.SSMIS.XCAL2016-V.20210110-S002714-E020909.088907.V05A.HDF5',
                                      scans=['S1'])

# %%
ssmis.read_data()
ssmis.read_sidecar_index()
ssmis.read_timestamps()
ssmis.read_sidecar_latlon()

# %%
ssmis.to_df()['S1']
# Out:
#               lat         lon                 sids                  timestamp  \
# 0      -72.609177  -41.255402  2299437706637111721 2021-01-10 00:27:16.000461
# 1      -72.648590  -42.054047  2299435211084507593 2021-01-10 00:27:16.000461
# 2      -72.691429  -42.852509  2299566194809236969 2021-01-10 00:27:16.000461
# 3      -72.737686  -43.650818  2299568020253779529 2021-01-10 00:27:16.000461
# 4      -72.787354  -44.448883  2299635836234516649 2021-01-10 00:27:16.000461
# ...           ...         ...                  ...                        ...
# 289885 -86.040787 -130.470047  2284328777475425993 2021-01-10 02:09:10.000288
# 289886 -86.277878 -130.970520  2284136116995049001 2021-01-10 02:09:10.000288
# 289887 -86.515533 -131.431442  2284137931351340937 2021-01-10 02:09:10.000288
# 289888 -86.753708 -131.844009  2284147551937067273 2021-01-10 02:09:10.000288
# 289889 -86.992317 -132.196808  2284115567354799209 2021-01-10 02:09:10.000288
#
# ...

# %%
ssmis.ts_start
# Out:
# '2021-01-10T00:27:14.800Z'
